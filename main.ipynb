# %%
import pandas as pd
import numpy as numpy

# %%
data=pd.read_csv("archive/train.csv")

# %%
data.head()
# Out:
#    beds  baths    size size_units  lot_size lot_size_units  zip_code  \
# 0     3    2.5  2590.0       sqft   6000.00           sqft     98144
# 1     4    2.0  2240.0       sqft      0.31           acre     98106
# 2     4    3.0  2040.0       sqft   3783.00           sqft     98107
# 3     4    3.0  3800.0       sqft   5175.00           sqft     98199
# 4     2    2.0  1042.0       sqft       NaN            NaN     98102
#
#        price
# 0   795000.0
# 1   915000.0
# 2   950000.0
# 3  1950000.0
# 4   950000.0

# %%
data.shape  ##returns the total number of rows and columns in the dataframe
# Out:
# (2016, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   beds            2016 non-null   int64
#  1   baths           2016 non-null   float64
#  2   size            2016 non-null   float64
#  3   size_units      2016 non-null   object
#  4   lot_size        1669 non-null   float64
#  5   lot_size_units  1669 non-null   object
#  6   zip_code        2016 non-null   int64
#  7   price           2016 non-null   float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 126.1+ KB

# %%
##extracting the every values in the column

# for column in data.columns:
# Loops through all column names in the DataFrame.
# print(data[column].value_counts())
# data[column] selects a specific column.
# .value_counts() returns the count of each unique value in that column.
# print("*"*20)
# Prints a separator of 20 asterisks (********************) after each column’s value counts to improve readability.


for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# beds
# 3     645
# 2     560
# 4     398
# 1     256
# 5     123
# 6      22
# 9       5
# 7       3
# 8       2
# 15      1
# 14      1
# Name: count, dtype: int64
# ********************
# baths
# 2.0    627
# 1.0    493
# 2.5    282
# 3.0    198
# 3.5    179
# 1.5    137
# 4.0     37
# 4.5     21
# 5.0     16
# 5.5     13
# 6.0      5
# 7.0      4
# 8.5      1
# 0.5      1
# 9.0      1
# 6.5      1
# Name: count, dtype: int64
# ********************
# size
# 2080.0    12
# 1440.0    11
# 1460.0    11
# 1370.0    11
# 1670.0    11
#           ..
# 1548.0     1
# 1174.0     1
# 1865.0     1
# 578.0      1
# 795.0      1
# Name: count, Length: 879, dtype: int64
# ********************
# size_units
# sqft    2016
# Name: count, dtype: int64
# ********************
# lot_size
# 5000.0    61
# 4000.0    45
# 6000.0    38
# 1.0       26
# 4800.0    16
#           ..
# 745.0      1
# 5043.0     1
# 2256.0     1
# 8540.0     1
# 4267.0     1
# Name: count, Length: 959, dtype: int64
# ...

# %%
data.isna().sum()  ##check if there are any null values in the column
# Out:
# beds                0
# baths               0
# size                0
# size_units          0
# lot_size          347
# lot_size_units    347
# zip_code            0
# price               0
# dtype: int64

# %%
## data.fillna(0, inplace=True)  ##replaces every valus by 0

# %%
data.dropna()
# Out:
#       beds  baths    size size_units  lot_size lot_size_units  zip_code  \
# 0        3    2.5  2590.0       sqft   6000.00           sqft     98144
# 1        4    2.0  2240.0       sqft      0.31           acre     98106
# 2        4    3.0  2040.0       sqft   3783.00           sqft     98107
# 3        4    3.0  3800.0       sqft   5175.00           sqft     98199
# 5        2    2.0  1190.0       sqft      1.00           acre     98107
# ...    ...    ...     ...        ...       ...            ...       ...
# 2009     3    3.5  1680.0       sqft   1486.00           sqft     98126
# 2010     2    2.0  1400.0       sqft      0.34           acre     98199
# 2011     3    2.0  1370.0       sqft      0.50           acre     98112
# 2013     4    2.0  2140.0       sqft   6250.00           sqft     98199
# 2015     3    2.0  1710.0       sqft   4267.00           sqft     98133
#
#           price
# 0      795000.0
# 1      915000.0
# 2      950000.0
# 3     1950000.0
# ...

# %%
data.drop(columns=['lot_size','lot_size_units'],inplace=True)    ##drop out the selected columns

# %%
data
# Out:
#       beds  baths    size size_units  zip_code      price
# 0        3    2.5  2590.0       sqft     98144   795000.0
# 1        4    2.0  2240.0       sqft     98106   915000.0
# 2        4    3.0  2040.0       sqft     98107   950000.0
# 3        4    3.0  3800.0       sqft     98199  1950000.0
# 4        2    2.0  1042.0       sqft     98102   950000.0
# ...    ...    ...     ...        ...       ...        ...
# 2011     3    2.0  1370.0       sqft     98112   910000.0
# 2012     1    1.0   889.0       sqft     98121   550000.0
# 2013     4    2.0  2140.0       sqft     98199  1150000.0
# 2014     2    2.0   795.0       sqft     98103   590000.0
# 2015     3    2.0  1710.0       sqft     98133   659000.0
#
# [2016 rows x 6 columns]

# %%
data.shape
# Out:
# (2016, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   beds        2016 non-null   int64
#  1   baths       2016 non-null   float64
#  2   size        2016 non-null   float64
#  3   size_units  2016 non-null   object
#  4   zip_code    2016 non-null   int64
#  5   price       2016 non-null   float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 94.6+ KB

# %%
data.describe()
# Out:
#               beds        baths          size      zip_code         price
# count  2016.000000  2016.000000   2016.000000   2016.000000  2.016000e+03
# mean      2.857639     2.159970   1735.740575  98123.638889  9.636252e+05
# std       1.255092     1.002023    920.132591     22.650819  9.440954e+05
# min       1.000000     0.500000    250.000000  98101.000000  1.590000e+05
# 25%       2.000000     1.500000   1068.750000  98108.000000  6.017500e+05
# 50%       3.000000     2.000000   1560.000000  98117.000000  8.000000e+05
# 75%       4.000000     2.500000   2222.500000  98126.000000  1.105250e+06
# max      15.000000     9.000000  11010.000000  98199.000000  2.500000e+07

# %%
data['beds'].value_counts()
# Out:
# beds
# 3     645
# 2     560
# 4     398
# 1     256
# 5     123
# 6      22
# 9       5
# 7       3
# 8       2
# 15      1
# 14      1
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    beds  baths    size size_units  zip_code      price
# 0     3    2.5  2590.0       sqft     98144   795000.0
# 1     4    2.0  2240.0       sqft     98106   915000.0
# 2     4    3.0  2040.0       sqft     98107   950000.0
# 3     4    3.0  3800.0       sqft     98199  1950000.0
# 4     2    2.0  1042.0       sqft     98102   950000.0

# %% [markdown]
# price per sq feet

# %%
data['price_per_sqft']=data['price']*100000/data['size']

# %%
data["price_per_sqft"]
# Out:
# 0       3.069498e+07
# 1       4.084821e+07
# 2       4.656863e+07
# 3       5.131579e+07
# 4       9.117083e+07
#             ...
# 2011    6.642336e+07
# 2012    6.186727e+07
# 2013    5.373832e+07
# 2014    7.421384e+07
# 2015    3.853801e+07
# Name: price_per_sqft, Length: 2016, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   beds            2016 non-null   int64
#  1   baths           2016 non-null   float64
#  2   size            2016 non-null   float64
#  3   size_units      2016 non-null   object
#  4   zip_code        2016 non-null   int64
#  5   price           2016 non-null   float64
#  6   price_per_sqft  2016 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 110.4+ KB

# %%
data.describe()
# Out:
#               beds        baths          size      zip_code         price  \
# count  2016.000000  2016.000000   2016.000000   2016.000000  2.016000e+03
# mean      2.857639     2.159970   1735.740575  98123.638889  9.636252e+05
# std       1.255092     1.002023    920.132591     22.650819  9.440954e+05
# min       1.000000     0.500000    250.000000  98101.000000  1.590000e+05
# 25%       2.000000     1.500000   1068.750000  98108.000000  6.017500e+05
# 50%       3.000000     2.000000   1560.000000  98117.000000  8.000000e+05
# 75%       4.000000     2.500000   2222.500000  98126.000000  1.105250e+06
# max      15.000000     9.000000  11010.000000  98199.000000  2.500000e+07
#
#        price_per_sqft
# count    2.016000e+03
# mean     5.915851e+07
# std      8.327952e+07
# min      6.796117e+06
# 25%      4.452221e+07
# 50%      5.529762e+07
# 75%      6.595389e+07
# max      3.424658e+09

# %%
data
# Out:
#       beds  baths    size size_units  zip_code      price  price_per_sqft
# 0        3    2.5  2590.0       sqft     98144   795000.0    3.069498e+07
# 1        4    2.0  2240.0       sqft     98106   915000.0    4.084821e+07
# 2        4    3.0  2040.0       sqft     98107   950000.0    4.656863e+07
# 3        4    3.0  3800.0       sqft     98199  1950000.0    5.131579e+07
# 4        2    2.0  1042.0       sqft     98102   950000.0    9.117083e+07
# ...    ...    ...     ...        ...       ...        ...             ...
# 2011     3    2.0  1370.0       sqft     98112   910000.0    6.642336e+07
# 2012     1    1.0   889.0       sqft     98121   550000.0    6.186727e+07
# 2013     4    2.0  2140.0       sqft     98199  1150000.0    5.373832e+07
# 2014     2    2.0   795.0       sqft     98103   590000.0    7.421384e+07
# 2015     3    2.0  1710.0       sqft     98133   659000.0    3.853801e+07
#
# [2016 rows x 7 columns]

# %%
data['raj']=0

# %%
data
# Out:
#       beds  baths    size size_units  zip_code      price  price_per_sqft  raj
# 0        3    2.5  2590.0       sqft     98144   795000.0    3.069498e+07    0
# 1        4    2.0  2240.0       sqft     98106   915000.0    4.084821e+07    0
# 2        4    3.0  2040.0       sqft     98107   950000.0    4.656863e+07    0
# 3        4    3.0  3800.0       sqft     98199  1950000.0    5.131579e+07    0
# 4        2    2.0  1042.0       sqft     98102   950000.0    9.117083e+07    0
# ...    ...    ...     ...        ...       ...        ...             ...  ...
# 2011     3    2.0  1370.0       sqft     98112   910000.0    6.642336e+07    0
# 2012     1    1.0   889.0       sqft     98121   550000.0    6.186727e+07    0
# 2013     4    2.0  2140.0       sqft     98199  1150000.0    5.373832e+07    0
# 2014     2    2.0   795.0       sqft     98103   590000.0    7.421384e+07    0
# 2015     3    2.0  1710.0       sqft     98133   659000.0    3.853801e+07    0
#
# [2016 rows x 8 columns]

# %%
data.drop(columns=['raj'],inplace=True)

# %%
data
# Out:
#       beds  baths    size size_units  zip_code      price  price_per_sqft
# 0        3    2.5  2590.0       sqft     98144   795000.0    3.069498e+07
# 1        4    2.0  2240.0       sqft     98106   915000.0    4.084821e+07
# 2        4    3.0  2040.0       sqft     98107   950000.0    4.656863e+07
# 3        4    3.0  3800.0       sqft     98199  1950000.0    5.131579e+07
# 4        2    2.0  1042.0       sqft     98102   950000.0    9.117083e+07
# ...    ...    ...     ...        ...       ...        ...             ...
# 2011     3    2.0  1370.0       sqft     98112   910000.0    6.642336e+07
# 2012     1    1.0   889.0       sqft     98121   550000.0    6.186727e+07
# 2013     4    2.0  2140.0       sqft     98199  1150000.0    5.373832e+07
# 2014     2    2.0   795.0       sqft     98103   590000.0    7.421384e+07
# 2015     3    2.0  1710.0       sqft     98133   659000.0    3.853801e+07
#
# [2016 rows x 7 columns]

# %%
data.drop(columns=['size_units'],inplace=True)

# %%
data
# Out:
#       beds  baths    size  zip_code      price  price_per_sqft
# 0        3    2.5  2590.0     98144   795000.0    3.069498e+07
# 1        4    2.0  2240.0     98106   915000.0    4.084821e+07
# 2        4    3.0  2040.0     98107   950000.0    4.656863e+07
# 3        4    3.0  3800.0     98199  1950000.0    5.131579e+07
# 4        2    2.0  1042.0     98102   950000.0    9.117083e+07
# ...    ...    ...     ...       ...        ...             ...
# 2011     3    2.0  1370.0     98112   910000.0    6.642336e+07
# 2012     1    1.0   889.0     98121   550000.0    6.186727e+07
# 2013     4    2.0  2140.0     98199  1150000.0    5.373832e+07
# 2014     2    2.0   795.0     98103   590000.0    7.421384e+07
# 2015     3    2.0  1710.0     98133   659000.0    3.853801e+07
#
# [2016 rows x 6 columns]

# %%
data.shape
# Out:
# (2016, 6)

# %% [markdown]
# saving final data to be used

# %%
data.to_csv("archive/final_dataset.csv")

# %%
X=data.drop(columns=['price'])
Y=data['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
# test_size=0.2: Allocates 20% of the data for testing and the remaining 80% for training.
# (Example: If you have 100 samples, it takes 80 samples to train and 20 samples to test.)
# random_state=0: Ensures reproducibility by using a fixed random seed, meaning the same split occurs every time you run the code.

X_train, X_test, Y_train, Y_test = train_test_split (X,Y, test_size=0.2, random_state=0)

# %%
data.shape
# Out:
# (2016, 6)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (1612, 5)
# (1612,)

# %%
data.head()
# Out:
#    beds  baths    size  zip_code      price  price_per_sqft
# 0     3    2.5  2590.0     98144   795000.0    3.069498e+07
# 1     4    2.0  2240.0     98106   915000.0    4.084821e+07
# 2     4    3.0  2040.0     98107   950000.0    4.656863e+07
# 3     4    3.0  3800.0     98199  1950000.0    5.131579e+07
# 4     2    2.0  1042.0     98102   950000.0    9.117083e+07

# %% [markdown]
# applying linear regression

# %%
 column_trans= make_column_transformer((OneHotEncoder(sparse_output=False),['beds']),remainder='passthrough')

# %%
scaler=StandardScaler()

# %%
from sklearn.linear_model import LinearRegression

# %%
le=LinearRegression(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 le=LinearRegression(normalize=True)
#
# TypeError: LinearRegression.__init__() got an unexpected keyword argument 'normalize'

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
